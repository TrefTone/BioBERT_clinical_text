# %%
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from sklearn.metrics import f1_score
from kaggle_secrets import UserSecretsClient
from sklearn.model_selection import train_test_split

import wandb
import torch
import spacy
from spacy import displacy
nlp = spacy.blank('en')
from transformers import BertTokenizer
from torch.utils.data import TensorDataset
from transformers import BertForSequenceClassification

from torch.optim import AdamW
from transformers import get_linear_schedule_with_warmup
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# %%
try:
    user_secrets = UserSecretsClient()
    secret_value_0 = user_secrets.get_secret("wandb_api")
    wandb.login(key=secret_value_0)
    anony=None
except:
    anony = "must"
    print('If you want to use your W&B account, go to Add-ons -> Secrets and provide your W&B access token. Use the Label name as wandb_api. \nGet your W&B access token from here: https://wandb.ai/authorize')
    
    
    
wandb.init(project="PICO Evidence Summarization",name=f"11.PICO Evidence Summarization BioBert-Base-Cased-v1.2-Run 11")
# Out:
# If you want to use your W&B account, go to Add-ons -> Secrets and provide your W&B access token. Use the Label name as wandb_api.
# Get your W&B access token from here: https://wandb.ai/authorize
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.16.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240329_192717-e8onhfd8</code>
# Syncing run <strong><a href='https://wandb.ai/treftone/PICO%20Evidence%20Summarization/runs/e8onhfd8' target="_blank">11.PICO Evidence Summarization BioBert-Base-Cased-v1.2-Run 11</a></strong> to <a href='https://wandb.ai/treftone/PICO%20Evidence%20Summarization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/treftone/PICO%20Evidence%20Summarization' target="_blank">https://wandb.ai/treftone/PICO%20Evidence%20Summarization</a>
#  View run at <a href='https://wandb.ai/treftone/PICO%20Evidence%20Summarization/runs/e8onhfd8' target="_blank">https://wandb.ai/treftone/PICO%20Evidence%20Summarization/runs/e8onhfd8</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/treftone/PICO%20Evidence%20Summarization/runs/e8onhfd8?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
df=pd.read_csv('/kaggle/input/medical-transcripts/transcript_clean.csv')
df
# Out:
#       Unnamed: 0  audio_clipping  audio_clipping:confidence  \
# 0              0     no_clipping                     1.0000
# 1              1  light_clipping                     0.6803
# 2              2     no_clipping                     1.0000
# 3              3     no_clipping                     1.0000
# 4              4     no_clipping                     1.0000
# ...          ...             ...                        ...
# 6655        6655     no_clipping                     1.0000
# 6656        6656     no_clipping                     1.0000
# 6657        6657     no_clipping                     1.0000
# 6658        6658     no_clipping                     1.0000
# 6659        6659     no_clipping                     1.0000
#
#      background_noise_audible  background_noise_audible:confidence  \
# 0                 light_noise                               1.0000
# 1                    no_noise                               0.6803
# 2                    no_noise                               0.6655
# 3                 light_noise                               1.0000
# 4                    no_noise                               1.0000
# ...                       ...                                  ...
# 6655                 no_noise                               0.6076
# 6656                 no_noise                               0.7829
# 6657                 no_noise                               0.6061
# 6658                 no_noise                               0.8215
# 6659                 no_noise                               0.7989
#
#       overall_quality_of_the_audio    quiet_speaker  quiet_speaker:confidence  \
# 0                             3.33  audible_speaker                       1.0
# 1                             3.33  audible_speaker                       1.0
# 2                             3.33  audible_speaker                       1.0
# 3                             3.33  audible_speaker                       1.0
# 4                             4.67  audible_speaker                       1.0
# ...                            ...              ...                       ...
# 6655                          3.80  audible_speaker                       1.0
# 6656                          3.80  audible_speaker                       1.0
# 6657                          3.80  audible_speaker                       1.0
# 6658                          3.80  audible_speaker                       1.0
# 6659                          4.00  audible_speaker                       1.0
#
#       speaker_id                                      file_download  \
# 0       43453425  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 1       43719934  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 2       43719934  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 3       31349958  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 4       43719934  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# ...          ...                                                ...
# 6655    14353703  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 6656    15004831  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 6657    15004831  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 6658    15830408  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 6659    15004831  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
#
#                           file_name  \
# 0     1249120_43453425_58166571.wav
# 1     1249120_43719934_43347848.wav
# 2     1249120_43719934_53187202.wav
# 3     1249120_31349958_55816195.wav
# 4     1249120_43719934_82524191.wav
# ...                             ...
# 6655  1249120_14353703_45949288.wav
# 6656  1249120_15004831_26452554.wav
# 6657  1249120_15004831_64958100.wav
# 6658  1249120_15830408_92962528.wav
# 6659  1249120_15004831_80093096.wav
#
#                                                  phrase  writer_id  \
# 0                       When I remember her I feel down   21665495
# 1     When I carry heavy things I feel like breaking...   44088126
# 2             there is too much pain when i move my arm   44292353
# 3     My son had his lip pierced and it is swollen a...   43755034
# 4                My muscles in my lower back are aching   21665495
# ...                                                 ...        ...
# 6655  I feel a burning sensation in my guts about 2 ...   40925305
# 6656     I have a split on my thumb that will not heal.   43755034
# 6657                I feel a lot of pain in the joints.   43772689
# 6658        The area around my heart doesn't feel good.   44292353
# 6659                  I complain alot with skin allergy   44118742
#
#               prompt
# 0     Emotional pain
# 1          Back pain
# 2         Joint pain
# 3     Infected wound
# 4          Back pain
# ...              ...
# 6655    Stomach ache
# 6656      Open wound
# 6657      Joint pain
# 6658     Heart hurts
# 6659      Skin issue
#
# [6660 rows x 14 columns]

# %%
df['prompt'].value_counts()
# Out:
# prompt
# Acne                  328
# Shoulder pain         320
# Knee pain             314
# Joint pain            309
# Infected wound        305
# Cough                 293
# Feeling dizzy         283
# Muscle pain           282
# Ear ache              270
# Feeling cold          263
# Skin issue            263
# Head ache             263
# Heart hurts           263
# Stomach ache          261
# Back pain             261
# Hair falling out      254
# Neck pain             251
# Body feels weak       250
# Internal pain         248
# Blurry vision         246
# Emotional pain        241
# Hard to breath        232
# Injury from sports    230
# Foot ache             222
# Open wound            208
# Name: count, dtype: int64

# %%
evidence_labels = df.prompt.unique()

evidence_dict = {}
for index, evidence_labels in enumerate(evidence_labels):
    evidence_dict[evidence_labels] = index
evidence_dict
# Out:
# {'Emotional pain': 0,
#  'Back pain': 1,
#  'Joint pain': 2,
#  'Infected wound': 3,
#  'Foot ache': 4,
#  'Shoulder pain': 5,
#  'Injury from sports': 6,
#  'Skin issue': 7,
#  'Stomach ache': 8,
#  'Knee pain': 9,
#  'Heart hurts': 10,
#  'Hard to breath': 11,
#  'Head ache': 12,
#  'Body feels weak': 13,
#  'Feeling dizzy': 14,
#  'Open wound': 15,
#  'Internal pain': 16,
#  'Blurry vision': 17,
#  'Acne': 18,
#  'Muscle pain': 19,
#  'Hair falling out': 20,
#  'Neck pain': 21,
#  'Cough': 22,
#  'Ear ache': 23,
#  'Feeling cold': 24}

# %%
df['Tags Mapped'] = df.prompt.map(evidence_dict)
df
# Out:
#       Unnamed: 0  audio_clipping  audio_clipping:confidence  \
# 0              0     no_clipping                     1.0000
# 1              1  light_clipping                     0.6803
# 2              2     no_clipping                     1.0000
# 3              3     no_clipping                     1.0000
# 4              4     no_clipping                     1.0000
# ...          ...             ...                        ...
# 6655        6655     no_clipping                     1.0000
# 6656        6656     no_clipping                     1.0000
# 6657        6657     no_clipping                     1.0000
# 6658        6658     no_clipping                     1.0000
# 6659        6659     no_clipping                     1.0000
#
#      background_noise_audible  background_noise_audible:confidence  \
# 0                 light_noise                               1.0000
# 1                    no_noise                               0.6803
# 2                    no_noise                               0.6655
# 3                 light_noise                               1.0000
# 4                    no_noise                               1.0000
# ...                       ...                                  ...
# 6655                 no_noise                               0.6076
# 6656                 no_noise                               0.7829
# 6657                 no_noise                               0.6061
# 6658                 no_noise                               0.8215
# 6659                 no_noise                               0.7989
#
#       overall_quality_of_the_audio    quiet_speaker  quiet_speaker:confidence  \
# 0                             3.33  audible_speaker                       1.0
# 1                             3.33  audible_speaker                       1.0
# 2                             3.33  audible_speaker                       1.0
# 3                             3.33  audible_speaker                       1.0
# 4                             4.67  audible_speaker                       1.0
# ...                            ...              ...                       ...
# 6655                          3.80  audible_speaker                       1.0
# 6656                          3.80  audible_speaker                       1.0
# 6657                          3.80  audible_speaker                       1.0
# 6658                          3.80  audible_speaker                       1.0
# 6659                          4.00  audible_speaker                       1.0
#
#       speaker_id                                      file_download  \
# 0       43453425  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 1       43719934  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 2       43719934  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 3       31349958  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 4       43719934  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# ...          ...                                                ...
# 6655    14353703  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 6656    15004831  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 6657    15004831  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 6658    15830408  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
# 6659    15004831  https://ml.sandbox.cf3.us/cgi-bin/index.cgi?do...
#
#                           file_name  \
# 0     1249120_43453425_58166571.wav
# 1     1249120_43719934_43347848.wav
# 2     1249120_43719934_53187202.wav
# 3     1249120_31349958_55816195.wav
# 4     1249120_43719934_82524191.wav
# ...                             ...
# 6655  1249120_14353703_45949288.wav
# 6656  1249120_15004831_26452554.wav
# 6657  1249120_15004831_64958100.wav
# 6658  1249120_15830408_92962528.wav
# 6659  1249120_15004831_80093096.wav
#
#                                                  phrase  writer_id  \
# 0                       When I remember her I feel down   21665495
# 1     When I carry heavy things I feel like breaking...   44088126
# 2             there is too much pain when i move my arm   44292353
# 3     My son had his lip pierced and it is swollen a...   43755034
# 4                My muscles in my lower back are aching   21665495
# ...                                                 ...        ...
# 6655  I feel a burning sensation in my guts about 2 ...   40925305
# 6656     I have a split on my thumb that will not heal.   43755034
# 6657                I feel a lot of pain in the joints.   43772689
# 6658        The area around my heart doesn't feel good.   44292353
# 6659                  I complain alot with skin allergy   44118742
#
#               prompt  Tags Mapped
# 0     Emotional pain            0
# 1          Back pain            1
# 2         Joint pain            2
# 3     Infected wound            3
# 4          Back pain            1
# ...              ...          ...
# 6655    Stomach ache            8
# 6656      Open wound           15
# 6657      Joint pain            2
# 6658     Heart hurts           10
# 6659      Skin issue            7
#
# [6660 rows x 15 columns]

# %%
X_train, X_val, y_train, y_val = train_test_split(df.index.values,\
                                                  df['Tags Mapped'].values,\
                                                  test_size=0.15,\
                                                  random_state=42,\
                                                  stratify=df['Tags Mapped'].values)

# %%
df['data_type'] = ['not_set']*df.shape[0]

df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

# %%
df.groupby(['prompt', 'Tags Mapped', 'data_type']).count()
# Out:
#                                           Unnamed: 0  audio_clipping  \
# prompt             Tags Mapped data_type
# Acne               18          train             279             279
#                                val                49              49
# Back pain          1           train             222             222
#                                val                39              39
# Blurry vision      17          train             209             209
#                                val                37              37
# Body feels weak    13          train             212             212
#                                val                38              38
# Cough              22          train             249             249
#                                val                44              44
# Ear ache           23          train             229             229
#                                val                41              41
# Emotional pain     0           train             205             205
#                                val                36              36
# Feeling cold       24          train             224             224
#                                val                39              39
# Feeling dizzy      14          train             240             240
#                                val                43              43
# Foot ache          4           train             189             189
#                                val                33              33
# Hair falling out   20          train             216             216
#                                val                38              38
# Hard to breath     11          train             197             197
#                                val                35              35
# Head ache          12          train             223             223
#                                val                40              40
# Heart hurts        10          train             224             224
#                                val                39              39
# Infected wound     3           train             259             259
#                                val                46              46
# Injury from sports 6           train             195             195
#                                val                35              35
# Internal pain      16          train             211             211
#                                val                37              37
# Joint pain         2           train             263             263
#                                val                46              46
# Knee pain          9           train             267             267
#                                val                47              47
# Muscle pain        19          train             240             240
#                                val                42              42
# Neck pain          21          train             213             213
#                                val                38              38
# Open wound         15          train             177             177
#                                val                31              31
# Shoulder pain      5           train             272             272
#                                val                48              48
# Skin issue         7           train             224             224
#                                val                39              39
# Stomach ache       8           train             222             222
#                                val                39              39
#
#                                           audio_clipping:confidence  \
# prompt             Tags Mapped data_type
# Acne               18          train                            279
#                                val                               49
# Back pain          1           train                            222
#                                val                               39
# Blurry vision      17          train                            209
#                                val                               37
# Body feels weak    13          train                            212
#                                val                               38
# Cough              22          train                            249
#                                val                               44
# Ear ache           23          train                            229
#                                val                               41
# Emotional pain     0           train                            205
#                                val                               36
# Feeling cold       24          train                            224
#                                val                               39
# Feeling dizzy      14          train                            240
#                                val                               43
# Foot ache          4           train                            189
#                                val                               33
# Hair falling out   20          train                            216
#                                val                               38
# Hard to breath     11          train                            197
#                                val                               35
# Head ache          12          train                            223
#                                val                               40
# Heart hurts        10          train                            224
#                                val                               39
# Infected wound     3           train                            259
#                                val                               46
# Injury from sports 6           train                            195
#                                val                               35
# Internal pain      16          train                            211
#                                val                               37
# Joint pain         2           train                            263
#                                val                               46
# Knee pain          9           train                            267
#                                val                               47
# Muscle pain        19          train                            240
#                                val                               42
# Neck pain          21          train                            213
#                                val                               38
# Open wound         15          train                            177
#                                val                               31
# Shoulder pain      5           train                            272
#                                val                               48
# Skin issue         7           train                            224
#                                val                               39
# Stomach ache       8           train                            222
#                                val                               39
#
#                                           background_noise_audible  \
# prompt             Tags Mapped data_type
# Acne               18          train                           279
#                                val                              49
# Back pain          1           train                           222
#                                val                              39
# Blurry vision      17          train                           209
#                                val                              37
# Body feels weak    13          train                           212
#                                val                              38
# Cough              22          train                           249
#                                val                              44
# Ear ache           23          train                           229
#                                val                              41
# Emotional pain     0           train                           205
#                                val                              36
# Feeling cold       24          train                           224
#                                val                              39
# Feeling dizzy      14          train                           240
#                                val                              43
# Foot ache          4           train                           189
#                                val                              33
# Hair falling out   20          train                           216
#                                val                              38
# Hard to breath     11          train                           197
#                                val                              35
# Head ache          12          train                           223
#                                val                              40
# Heart hurts        10          train                           224
#                                val                              39
# Infected wound     3           train                           259
#                                val                              46
# Injury from sports 6           train                           195
#                                val                              35
# Internal pain      16          train                           211
#                                val                              37
# Joint pain         2           train                           263
#                                val                              46
# Knee pain          9           train                           267
#                                val                              47
# Muscle pain        19          train                           240
#                                val                              42
# Neck pain          21          train                           213
#                                val                              38
# Open wound         15          train                           177
#                                val                              31
# Shoulder pain      5           train                           272
#                                val                              48
# Skin issue         7           train                           224
#                                val                              39
# Stomach ache       8           train                           222
#                                val                              39
#
#                                           background_noise_audible:confidence  \
# prompt             Tags Mapped data_type
# Acne               18          train                                      279
#                                val                                         49
# Back pain          1           train                                      222
#                                val                                         39
# Blurry vision      17          train                                      209
#                                val                                         37
# Body feels weak    13          train                                      212
#                                val                                         38
# Cough              22          train                                      249
#                                val                                         44
# Ear ache           23          train                                      229
#                                val                                         41
# Emotional pain     0           train                                      205
#                                val                                         36
# Feeling cold       24          train                                      224
#                                val                                         39
# Feeling dizzy      14          train                                      240
#                                val                                         43
# Foot ache          4           train                                      189
#                                val                                         33
# Hair falling out   20          train                                      216
#                                val                                         38
# Hard to breath     11          train                                      197
#                                val                                         35
# Head ache          12          train                                      223
#                                val                                         40
# Heart hurts        10          train                                      224
#                                val                                         39
# Infected wound     3           train                                      259
#                                val                                         46
# Injury from sports 6           train                                      195
#                                val                                         35
# Internal pain      16          train                                      211
#                                val                                         37
# Joint pain         2           train                                      263
#                                val                                         46
# Knee pain          9           train                                      267
#                                val                                         47
# Muscle pain        19          train                                      240
#                                val                                         42
# Neck pain          21          train                                      213
#                                val                                         38
# Open wound         15          train                                      177
#                                val                                         31
# Shoulder pain      5           train                                      272
#                                val                                         48
# Skin issue         7           train                                      224
#                                val                                         39
# Stomach ache       8           train                                      222
#                                val                                         39
#
#                                           overall_quality_of_the_audio  \
# prompt             Tags Mapped data_type
# Acne               18          train                               279
#                                val                                  49
# Back pain          1           train                               222
#                                val                                  39
# Blurry vision      17          train                               209
#                                val                                  37
# Body feels weak    13          train                               212
#                                val                                  38
# Cough              22          train                               249
#                                val                                  44
# Ear ache           23          train                               229
#                                val                                  41
# Emotional pain     0           train                               205
#                                val                                  36
# Feeling cold       24          train                               224
#                                val                                  39
# Feeling dizzy      14          train                               240
#                                val                                  43
# Foot ache          4           train                               189
#                                val                                  33
# Hair falling out   20          train                               216
#                                val                                  38
# Hard to breath     11          train                               197
#                                val                                  35
# Head ache          12          train                               223
#                                val                                  40
# Heart hurts        10          train                               224
#                                val                                  39
# Infected wound     3           train                               259
#                                val                                  46
# Injury from sports 6           train                               195
#                                val                                  35
# Internal pain      16          train                               211
#                                val                                  37
# Joint pain         2           train                               263
#                                val                                  46
# Knee pain          9           train                               267
#                                val                                  47
# Muscle pain        19          train                               240
#                                val                                  42
# Neck pain          21          train                               213
#                                val                                  38
# Open wound         15          train                               177
#                                val                                  31
# Shoulder pain      5           train                               272
#                                val                                  48
# Skin issue         7           train                               224
#                                val                                  39
# Stomach ache       8           train                               222
#                                val                                  39
#
#                                           quiet_speaker  \
# prompt             Tags Mapped data_type
# Acne               18          train                279
#                                val                   49
# Back pain          1           train                222
#                                val                   39
# Blurry vision      17          train                209
#                                val                   37
# Body feels weak    13          train                212
#                                val                   38
# Cough              22          train                249
#                                val                   44
# Ear ache           23          train                229
#                                val                   41
# Emotional pain     0           train                205
#                                val                   36
# Feeling cold       24          train                224
#                                val                   39
# Feeling dizzy      14          train                240
#                                val                   43
# Foot ache          4           train                189
#                                val                   33
# Hair falling out   20          train                216
#                                val                   38
# Hard to breath     11          train                197
#                                val                   35
# Head ache          12          train                223
#                                val                   40
# Heart hurts        10          train                224
#                                val                   39
# Infected wound     3           train                259
#                                val                   46
# Injury from sports 6           train                195
#                                val                   35
# Internal pain      16          train                211
#                                val                   37
# Joint pain         2           train                263
#                                val                   46
# Knee pain          9           train                267
#                                val                   47
# Muscle pain        19          train                240
#                                val                   42
# Neck pain          21          train                213
#                                val                   38
# Open wound         15          train                177
#                                val                   31
# Shoulder pain      5           train                272
#                                val                   48
# Skin issue         7           train                224
#                                val                   39
# Stomach ache       8           train                222
#                                val                   39
#
#                                           quiet_speaker:confidence  \
# prompt             Tags Mapped data_type
# Acne               18          train                           279
#                                val                              49
# Back pain          1           train                           222
#                                val                              39
# Blurry vision      17          train                           209
#                                val                              37
# Body feels weak    13          train                           212
#                                val                              38
# Cough              22          train                           249
#                                val                              44
# Ear ache           23          train                           229
#                                val                              41
# Emotional pain     0           train                           205
#                                val                              36
# Feeling cold       24          train                           224
#                                val                              39
# Feeling dizzy      14          train                           240
#                                val                              43
# Foot ache          4           train                           189
#                                val                              33
# Hair falling out   20          train                           216
#                                val                              38
# Hard to breath     11          train                           197
#                                val                              35
# Head ache          12          train                           223
#                                val                              40
# Heart hurts        10          train                           224
#                                val                              39
# Infected wound     3           train                           259
#                                val                              46
# Injury from sports 6           train                           195
#                                val                              35
# Internal pain      16          train                           211
#                                val                              37
# Joint pain         2           train                           263
#                                val                              46
# Knee pain          9           train                           267
#                                val                              47
# Muscle pain        19          train                           240
#                                val                              42
# Neck pain          21          train                           213
#                                val                              38
# Open wound         15          train                           177
#                                val                              31
# Shoulder pain      5           train                           272
#                                val                              48
# Skin issue         7           train                           224
#                                val                              39
# Stomach ache       8           train                           222
#                                val                              39
#
#                                           speaker_id  file_download  \
# prompt             Tags Mapped data_type
# Acne               18          train             279            279
#                                val                49             49
# Back pain          1           train             222            222
#                                val                39             39
# Blurry vision      17          train             209            209
#                                val                37             37
# Body feels weak    13          train             212            212
#                                val                38             38
# Cough              22          train             249            249
#                                val                44             44
# Ear ache           23          train             229            229
#                                val                41             41
# Emotional pain     0           train             205            205
#                                val                36             36
# Feeling cold       24          train             224            224
#                                val                39             39
# Feeling dizzy      14          train             240            240
#                                val                43             43
# Foot ache          4           train             189            189
#                                val                33             33
# Hair falling out   20          train             216            216
#                                val                38             38
# Hard to breath     11          train             197            197
#                                val                35             35
# Head ache          12          train             223            223
#                                val                40             40
# Heart hurts        10          train             224            224
#                                val                39             39
# Infected wound     3           train             259            259
#                                val                46             46
# Injury from sports 6           train             195            195
#                                val                35             35
# Internal pain      16          train             211            211
#                                val                37             37
# Joint pain         2           train             263            263
#                                val                46             46
# Knee pain          9           train             267            267
#                                val                47             47
# Muscle pain        19          train             240            240
#                                val                42             42
# Neck pain          21          train             213            213
#                                val                38             38
# Open wound         15          train             177            177
#                                val                31             31
# Shoulder pain      5           train             272            272
#                                val                48             48
# Skin issue         7           train             224            224
#                                val                39             39
# Stomach ache       8           train             222            222
#                                val                39             39
#
#                                           file_name  phrase  writer_id
# prompt             Tags Mapped data_type
# Acne               18          train            279     279        279
#                                val               49      49         49
# Back pain          1           train            222     222        222
#                                val               39      39         39
# Blurry vision      17          train            209     209        209
#                                val               37      37         37
# Body feels weak    13          train            212     212        212
#                                val               38      38         38
# Cough              22          train            249     249        249
#                                val               44      44         44
# Ear ache           23          train            229     229        229
#                                val               41      41         41
# Emotional pain     0           train            205     205        205
#                                val               36      36         36
# Feeling cold       24          train            224     224        224
#                                val               39      39         39
# Feeling dizzy      14          train            240     240        240
#                                val               43      43         43
# Foot ache          4           train            189     189        189
#                                val               33      33         33
# Hair falling out   20          train            216     216        216
#                                val               38      38         38
# Hard to breath     11          train            197     197        197
#                                val               35      35         35
# Head ache          12          train            223     223        223
#                                val               40      40         40
# Heart hurts        10          train            224     224        224
#                                val               39      39         39
# Infected wound     3           train            259     259        259
#                                val               46      46         46
# Injury from sports 6           train            195     195        195
#                                val               35      35         35
# Internal pain      16          train            211     211        211
#                                val               37      37         37
# Joint pain         2           train            263     263        263
#                                val               46      46         46
# Knee pain          9           train            267     267        267
#                                val               47      47         47
# Muscle pain        19          train            240     240        240
#                                val               42      42         42
# Neck pain          21          train            213     213        213
#                                val               38      38         38
# Open wound         15          train            177     177        177
#                                val               31      31         31
# Shoulder pain      5           train            272     272        272
#                                val               48      48         48
# Skin issue         7           train            224     224        224
#                                val               39      39         39
# Stomach ache       8           train            222     222        222
#                                val               39      39         39

# %%
tokenizer = BertTokenizer.from_pretrained('dmis-lab/biobert-base-cased-v1.2', do_lower_case=True,truncation=True)
# Out:
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.11k [00:00<?, ?B/s]

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].phrase.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    truncation=True,
    padding='longest', 
    max_length=512, 
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type=='val'].phrase.values, 
    add_special_tokens=True, 
    truncation=True,
    return_attention_mask=True, 
    padding='longest', 
    max_length=512, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
tags_train = torch.tensor(df[df.data_type=='train']['Tags Mapped'].values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
tags_val = torch.tensor(df[df.data_type=='val']['Tags Mapped'].values)

# %%
dataset_train = TensorDataset(input_ids_train, attention_masks_train, tags_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, tags_val)

# %%
print(len(dataset_train), len(dataset_val))
# Out:
# 5661 999

# %% [markdown]
# ## Model Training

# %%
model = BertForSequenceClassification.from_pretrained("dmis-lab/biobert-base-cased-v1.2",
                                                      num_labels=len(evidence_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
batch_size = 16 #Defining Batch Size on which model has to be trained

# Converting tensors Dataset to dataloaders so that model can be trained
dataloader_train = DataLoader(dataset_train,sampler=RandomSampler(dataset_train), batch_size=batch_size) 

dataloader_validation = DataLoader(dataset_val, sampler=SequentialSampler(dataset_val), batch_size=batch_size)

# %%
optimizer = AdamW(model.parameters(),lr=1e-5, eps=1e-8) # Initializing Adam Weight Decay Optimizer with its parameters

# %%
epochs = 15
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0,num_training_steps=len(dataloader_train)*epochs)

# %%
def f1_score_func(preds, tags):
    preds_flat = np.argmax(preds, axis=1).flatten()
    tags_flat = tags.flatten()
    return f1_score(tags_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, tags):
    evidence_dict_inverse = {v: k for k, v in evidence_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    tags_flat = tags.flatten()

    for tag in np.unique(tags_flat):
        y_preds = preds_flat[tags_flat==tag]
        y_true = tags_flat[tags_flat==tag]
        print(f'PICO Evidence Class: {evidence_dict_inverse[tag]}')
        print(f'Accuracy: {len(y_preds[y_preds==tag])}/{len(y_true)}\n')

# %%
seed_val = 199
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
# !mkdir models #creating Directory for model storing
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
loss_train_avg_list = []
val_loss_list = []
val_f1_list = []

for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
    torch.save(model.state_dict(), f'models/finetuned_BioBERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    loss_train_avg_list.append(loss_train_avg)
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    val_loss_list.append(val_loss)
    tqdm.write(f'F1 validation Score (Weighted): {val_f1}')
    val_f1_list.append(val_f1)
    wandb.log({"Training loss":loss_train_avg, "Validation loss":val_loss,"F1 validation Score (Weighted)":val_f1,})
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 1
# Training loss: 2.2114178654500996
# Validation loss: 0.7500470356335716
# F1 validation Score (Weighted): 0.9082377485644458
# Epoch 2:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 2
# Training loss: 0.4192855064941328
# Validation loss: 0.10793884340969342
# F1 validation Score (Weighted): 0.9939863315926843
# Epoch 3:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 3
# Training loss: 0.07326156291900213
# Validation loss: 0.041587058513883564
# F1 validation Score (Weighted): 0.9919760460458135
# Epoch 4:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 4
# Training loss: 0.0275428163855847
# Validation loss: 0.023854182101786137
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 5:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 5
# Training loss: 0.014880253909692422
# Validation loss: 0.02118559406390266
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 6:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 6
# Training loss: 0.00965037937065597
# Validation loss: 0.020181804307780805
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 7:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 7
# Training loss: 0.007032536197779963
# Validation loss: 0.01974963781512564
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 8:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 8
# Training loss: 0.007075856988960193
# Validation loss: 0.019744387750203412
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 9:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 9
# Training loss: 0.004694829399613295
# Validation loss: 0.01987870921942568
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 10:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 10
# Training loss: 0.004117635334578822
# Validation loss: 0.018992891867778132
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 11:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 11
# Training loss: 0.003169516580952805
# Validation loss: 0.018532192201486657
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 12:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 12
# Training loss: 0.0024506815920957484
# Validation loss: 0.019534871333263933
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 13:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 13
# Training loss: 0.0021441864043126924
# Validation loss: 0.01976530436640753
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 14:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 14
# Training loss: 0.0020019903826385232
# Validation loss: 0.019213268507478967
# F1 validation Score (Weighted): 0.9980070770768446
# Epoch 15:   0%|          | 0/354 [00:00<?, ?it/s]
# Epoch 15
# Training loss: 0.0019180942898995039
# Validation loss: 0.019320027416734588
# F1 validation Score (Weighted): 0.9980070770768446

# %%
model.load_state_dict(torch.load('models/finetuned_BioBERT_epoch_8.model', map_location=torch.device('cuda')))
# Out:
# <All keys matched successfully>

# %%
sns.set(style='darkgrid')

sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)


plt.plot(loss_train_avg_list, 'b-o')

plt.title("Training loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %%
sns.set(style='darkgrid')

sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)


plt.plot(val_loss_list, 'b-o')

plt.title("Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %%
sns.set(style='darkgrid')

sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)


plt.plot(val_f1_list, 'b-o')

plt.title("Validation F1 Score")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>F1 validation Score (Weighted)</td><td>▁██████████████</td></tr><tr><td>Training loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Validation loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>F1 validation Score (Weighted)</td><td>0.99801</td></tr><tr><td>Training loss</td><td>0.00192</td></tr><tr><td>Validation loss</td><td>0.01932</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">11.PICO Evidence Summarization BioBert-Base-Cased-v1.2-Run 11</strong> at: <a href='https://wandb.ai/treftone/PICO%20Evidence%20Summarization/runs/e8onhfd8' target="_blank">https://wandb.ai/treftone/PICO%20Evidence%20Summarization/runs/e8onhfd8</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240329_192717-e8onhfd8/logs</code>

# %%
_, predictions, true_vals = evaluate(dataloader_validation)

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# PICO Evidence Class: Emotional pain
# Accuracy: 36/36
#
# PICO Evidence Class: Back pain
# Accuracy: 38/39
#
# PICO Evidence Class: Joint pain
# Accuracy: 46/46
#
# PICO Evidence Class: Infected wound
# Accuracy: 46/46
#
# PICO Evidence Class: Foot ache
# Accuracy: 32/33
#
# PICO Evidence Class: Shoulder pain
# Accuracy: 48/48
#
# PICO Evidence Class: Injury from sports
# Accuracy: 35/35
#
# PICO Evidence Class: Skin issue
# Accuracy: 39/39
#
# PICO Evidence Class: Stomach ache
# Accuracy: 39/39
#
# PICO Evidence Class: Knee pain
# Accuracy: 47/47
#
# PICO Evidence Class: Heart hurts
# Accuracy: 39/39
#
# PICO Evidence Class: Hard to breath
# Accuracy: 35/35
#
# PICO Evidence Class: Head ache
# Accuracy: 40/40
#
# PICO Evidence Class: Body feels weak
# Accuracy: 38/38
#
# PICO Evidence Class: Feeling dizzy
# Accuracy: 43/43
#
# PICO Evidence Class: Open wound
# Accuracy: 31/31
#
# PICO Evidence Class: Internal pain
# Accuracy: 37/37
#
# PICO Evidence Class: Blurry vision
# Accuracy: 37/37
#
# PICO Evidence Class: Acne
# Accuracy: 49/49
#
# PICO Evidence Class: Muscle pain
# Accuracy: 42/42
#
# PICO Evidence Class: Hair falling out
# Accuracy: 38/38
#
# PICO Evidence Class: Neck pain
# Accuracy: 38/38
#
# PICO Evidence Class: Cough
# Accuracy: 44/44
#
# PICO Evidence Class: Ear ache
# Accuracy: 41/41
#
# PICO Evidence Class: Feeling cold
# Accuracy: 39/39

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("transcript")

# %%
# !sudo apt-get install git-lfs
# !git lfs install
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.9.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Error: Failed to call git rev-parse --git-dir: exit status 128
# Git LFS initialized.

# %%
model.push_to_hub(repo_id='samirangupta31/MedicalTranscripts', use_auth_token='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')
# Out:
# CommitInfo(commit_url='https://huggingface.co/samirangupta31/MedicalTranscripts/commit/d5c6d3809338a9eb7bb8080234d2f8db13d6bccf', commit_message='Upload BertForSequenceClassification', commit_description='', oid='d5c6d3809338a9eb7bb8080234d2f8db13d6bccf', pr_url=None, pr_revision=None, pr_num=None)

# %%
tokenizer.push_to_hub(repo_id='samirangupta31/MedicalTranscripts', use_auth_token='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')
# Out:
# CommitInfo(commit_url='https://huggingface.co/samirangupta31/MedicalTranscripts/commit/d41205a4cd1e6c03c69cbf6a54381e1ba4050492', commit_message='Upload tokenizer', commit_description='', oid='d41205a4cd1e6c03c69cbf6a54381e1ba4050492', pr_url=None, pr_revision=None, pr_num=None)
